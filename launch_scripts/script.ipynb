# %%
import os

if not os.path.exists("/home/project_AML_24_25"):
  # %mkdir "/home/project_AML_24_25"

# %cd "/home/project_AML_24_25"

# Unzip the datasets on the Colab VM disk
# !unzip "/drive/Task Arithmetic Datasets/*" -d "/home/project_AML_24_25/datasets/"

# %%
### REMEMBER to set the arguments of the launch scripts before launching them

# Clone the code
# %cd "/home/project_AML_24_25/"
# !git clone "https://github.com/giuseppedenigris/polito-task-arithmetic.git"
# %cd "/home/project_AML_24_25/polito-task-arithmetic/"
# !pip install -r requirements.txt

# %%
# %cd "/home/project_AML_24_25/polito-task-arithmetic/"

# Launch scripts
# !sh "launch_scripts/base.sh"
